# %%
import re
def remove_non_ascii(text):
    return re.sub(r'[^\x00-\x7F]+', '', str(text))

# %%
import pandas as pd
import json

with open('_-E_Mail_senden.txt', 'r') as f:
  json_string = f.read()
  



data = json.loads(json_string)


data
# Out:
# {'E_Mail_senden_Identit_t': None,
#  'Geburtsjahr': 2003,
#  'Owner': {'name': 'Andreas Noack',
#   'id': '318777000017206719',
#   'email': 'andreasnoack@migrando.de'},
#  'Antrag_NE_wann_gestellt': None,
#  'Einreisejahr': 'In Deutschland geboren',
#  'Info_zum_Ehepartner': None,
#  '$field_states': None,
#  'Sprachzertifikat_1': ['Deutscher Schulabschluss'],
#  'Sonstige_Details_EB': None,
#  'Erh_lt_Bedarfsgemeinschaft_Geld_vom_Jobcenter': 'Nein',
#  'Interesse_neues_Gesetz': True,
#  'Nationalpass_Ausnahme1': None,
#  '$process_flow': False,
#  'Currency': 'EUR',
#  'Einreisejahr_Deutschland': '2018-11-01',
#  'EB_neues_Gesetz': 'Nein',
#  'Preis_Raten_EB': '149.00',
#  '$approval': {'delegate': False,
#   'approve': False,
#   'reject': False,
#   'resubmit': False},
#  'First_Visited_URL': 'https://migrando.de/linktree/',
#  'Anspruchsgrundlage1': None,
#  'CRM_Campaigns': [],
#  'Gr_nde_f_r_Ablehnung_EB': None,
#  'Familienstand': 'ledig',
#  'Mandat_gek_ndigt': False,
#  'Land': None,
#  'Anrede1': 'Herr',
#  'Beratung': 'Ja',
#  'Aufenthaltstitel_Telefon_NEU': '32',
#  'Antrag_EB_wann_gestellt': 'Vor mehr als 1 Jahr',
#  'Abschluss_in_DE': 'Ja',
#  'Datum_letzter_Test_mit_Zeit': '2024-01-14T02:32:00+01:00',
#  'Number_Of_Chats': 0,
#  'Datum_Eintrag_Beratung_sp_ter': None,
#  'Anzahl_der_Raten_NE2': None,
#  '$review_process': {'approve': False, 'reject': False, 'resubmit': False},
#  'Other_Zip': '22145',
#  'Mailing_Street': 'LehÃ\xa0r StraÃŸe 62a',
#  'E_Mail_nach_Telefonberatung': None,
#  'Average_Time_Spent_Minutes': 3.66,
#  'Setter_2_optional': None,
#  'Sales': 1,
#  'E_Mail_Vollmacht_Kontakt': None,
#  'Rechtm_iger_Aufenthalt_seit': None,
#  'Ende_Duldung': None,
#  'Nationalit_t': 'Iran',
#  'Bearbeitungshinweis_Kanzlei': None,
#  'Other_Street': 'LehÃ\xa0r StraÃŸe 62a',
#  'Woo_ID_NE': None,
#  'Unterlagen_Mail_erstellen': None,
#  'Woo_ID_Identit_t': None,
#  'Berufsausbildung': 'Ungelernt',
#  'Jahr_Ausbildung_abgeschlossen': None,
#  'Test_Sprache': 'Deutsch',
#  'Deutscher_Ehepartner': None,
#  'EB_erhalten_am': None,
#  'Datum_der_Doppelbuchung': None,
#  '$orchestration': False,
#  'Datum_letzter_Anruf_Ausagehend_Eingehend': '2024-05-24T13:14:11+02:00',
#  'Geburtsdatum_aus_Formular_EB': None,
#  'Beratung_war_Ja_Backup': True,
#  'Lead_Test_Feld': None,
#  'Layout': {'name': 'Sales Mitarbeiter', 'id': '318777000000032039'},
#  'Vollmacht_EB': None,
#  'Herkunftsland': None,
#  'Lead_Source': 'TikTok',
#  'Last_Missed_Call': '2024-05-27T11:39:17+02:00',
#  'E_Mail_Adresse': None,
#  'Email': 'maniibkh@gmail.com',
#  '$currency_symbol': '€',
#  'Visitor_Score': '653',
#  'Einkommen_netto_pro_Monat': 950,
#  'Missed_Calls': 5,
#  'Other_State': 'Nordrheinwestfalen',
#  'Ausgang_Antragsverfahren_EB': None,
#  'Followup_After_Sale': [],
#  'Nachname_Woo': 'Bakhtiari',
#  'Last_Activity_Time': '2024-05-27T11:45:59+02:00',
#  'Kaufdatum_Last_Woo': '2024-05-23 19:49:38',
#  'Produkt_NE': None,
#  'Contact_ID': '318777000145496147',
#  'Unsubscribed_Mode': None,
#  'Woo_ID_Erstberatung': None,
#  'Exchange_Rate': 1,
#  'Test': None,
#  'Kinder': '0',
#  '$approved': True,
#  'Daten_vom_Kunden_aktualisiert_am': None,
#  'Whatsapp': '4917632604730',
#  'Rente': '48 - 60 Monate',
#  'E_Mail_EB_individuell': None,
#  'Rentenbeitr_ge_genau': '0',
#  'Erreichbarkeit': None,
#  'Bemerkungen_Doppelbuchung': None,
#  'Other_City': 'hamburg',
#  'utm_campaign': 'linktree',
#  'Vollmacht_manuelle_EIngabe': None,
#  'Setter_gesetzt_Datum': '2024-04-23T14:25:00+02:00',
#  'Number_of_Deals': 1,
#  'Alter_Formel': 21,
#  'Home_Phone': '+4917632604730',
#  'Einkommensart': ['Arbeitsvertrag (Nebenjob)'],
#  'zohoworkdriveforcrm__Workdrive_Folder_ID': 'ecqct12448b53fb4d4c96a7ff59795d7640c1',
#  'Datum_R_ckzahlung': None,
#  'Sales_Niederlassungserlaubnis': 0,
#  'E_Mail_Woo': 'maniibkh@gmail.com',
#  'Probleme_mit_Ausl_nderbeh_rde_Telefon': None,
#  '$zia_owner_assignment': 'owner_recommendation_unavailable',
#  'Status_der_Doppelbuchung': None,
#  'Anzahl_der_Raten_EB2': 12,
#  'Email_und_Termin_best_tigen': 'Ja (E-Mail an Kunde wird in 60min ausgelÃ¶st + Kalendereintrag + Chatnachricht an Setter/Closer)',
#  'utm_source': 'tiktok',
#  'Dynamischer_Buchungsink_Email_senden': None,
#  'Gutschein': None,
#  'Netto': '0€ bis 600€',
#  'Mailing_Zip': '22145',
#  'Buchhaltung_gepr_ft': None,
#  'Datum_des_Antrags': None,
#  'Anspruchsgrundlage': None,
#  'Sales_Erstberatung': 0,
#  'Modified_By': {'name': 'Sebastian Stein',
#   'id': '318777000000239001',
#   'email': 'sebastianstein@migrando.de'},
#  '$review': None,
#  'Datum_des_Sales': '2024-05-23T19:49:38+02:00',
#  'First_Missed_Call': '2024-05-24T17:03:29+02:00',
#  'Minderj_rhig': 'Einreise jÃ¼nger als 18',
#  'Welches_Aufenthaltsrecht_haben_Sie_aktuell': 'ACHTUNG TEST 3.0',
#  'utm_content': None,
#  'Social_Media_ID': None,
#  'Stadt_Woo': 'hamburg',
#  'Modified_Time': '2024-05-27T11:45:59+02:00',
#  'Date_of_Birth': None,
#  'Telefon_Woo': '017632604730',
#  'E_Mail_Vollmacht_Ehepartner': None,
#  'Anrede': None,
#  'First_Visited_Time': '2024-01-14T02:30:18+01:00',
#  'ID_der_Doppelbuchung': None,
#  'G_ltiger_Nationalpass': 'Ja',
#  '$in_merge': False,
#  'Referrer': 'https://www.tiktok.com/',
#  'Grund_der_Absage': ['Voraussetzungen nicht erfÃ¼llt'],
#  'Owner_Backup_Status': None,
#  'Nachname_Backup': 'Bakhtiari',
#  '$approval_state': 'approved',
#  'Dynamischer_Buchungslink': None,
#  'Identit_t_gesichert_Stufe_3a': ['Personalausweis (z.B. Tazkira)',
#   'Geburtsurkunde'],
#  'Beratung_Ja_Nein': None,
#  'Geburtsdatum_aus_Formular': None,
#  'Stornierte_Sales_Insgesamt': 0,
#  'E_Mail_senden_Support': None,
#  'Mailing_State': 'Nordrheinwestfalen',
#  'Multizeile_2': '23.05.2024 will Raten zahlung wolte wissen warum nicht paypal geht will mit iban spÃ¤ter buchen\n\n23.04.2024 15:00 will Ã¼berlegen Ablauf und kosten bekannt -> Vater will das er deutscher wird\n\nDienstag 15Uhr ist auf Arbeit \nNE mÃ¶glich \nund EB mÃ¶glich\n\nSein Vater wÃ¼rde das bezahlen \n\nIst hier geboren \n\n22.01.2024 14:00 will mit Vater heute Abend buchen\n\nhat Job arbeitet Jetzt\nhat Schulabschluss\nNeues Gesetz \n\ner macht Untermiete \nwohnt bei seinem Vater er ist Elektriker...\nDer Vater bÃ¼rgt/sorgt fÃ¼r seinen Sohn',
#  'Test9': None,
#  'Test8': None,
#  'Test7': None,
#  'Setter_3_optional': None,
#  'Test6': None,
#  'Anzahl_Kinder_unter_25_Jahre': '0',
#  'Test5': None,
#  'Test4': None,
#  'Other_Country': 'Germany',
#  'Erreichbarkeit_Uhrzeit_Liste': [],
#  'Test3': None,
#  'Google_und_Trustpilot_Bewertung': None,
#  'Test2': None,
#  'Jahr_AR_beantragt_bekommen': '2019',
#  'Wohnraum': 'Mietwohnung',
#  'Zoho_Books_ID': None,
#  'Haben_Sie_bereits_einen_Antrag_auf_Einb_rgerung_ge': 'Ja, mein Antrag wird aktuell bearbeitet',
#  '$state': 'save',
#  'Sonstiges_befristetes_AR_Aufenthaltstitel1': None,
#  'id': '318777000096411067',
#  'Vollmacht': 'Ja',
#  'missed_calls1': None,
#  'Beschreibe_den_Strafvorwurf': None,
#  'Vollmacht_Identit_t': None,
#  'Created_Time': '2024-01-14T02:32:15+01:00',
#  'E_Mail_senden_Einb_rgerung': 'Zusage EinbÃ¼rgerung',
#  'Sprachzertifikat1': 'Nein',
#  'Rechnung_stellen': False,
#  'Erreichbarkeit_Uhrzeit': [],
#  'Integrationsnachweis_1': ['Deutscher Schulabschluss'],
#  'reset': None,
#  'Einb_rgerungszusicherung': None,
#  'Preis_Raten_NE': None,
#  'Last_Visited_Time': '2024-05-23T21:56:28+02:00',
#  'Created_By': {'name': 'Sebastian Stein',
#   'id': '318777000000239001',
#   'email': 'sebastianstein@migrando.de'},
#  'Stra_e_u_Hausnummer': 'LehÃ\xa0r StraÃŸe 62a',
#  'Beziehung_Letzter_Test_Anruf': -3154.7,
#  'Quantity_Products': '1',
#  'Kaufdatum_NE': None,
#  'Datum_des_Antrags_EB': None,
#  'ID_Stufe_3': None,
#  '$canvas_id': None,
#  'Last_updated_by': None,
#  'Salutation': 'Herr',
#  'Erreichbarkeit_Datum_Zeit': None,
#  'Full_Name': 'Herr Mani Bakhtiari',
#  'zohoworkdriveforcrm__Workdrive_Folder_URL': 'https://workdrive.zoho.eu/folder/ecqct12448b53fb4d4c96a7ff59795d7640c1',
#  'Kaufdatum_First_Woo': '2024-05-23 19:49:38',
#  'Minderj_hrige_Kinder_Antragsteller': '0',
#  'Welchen_Fl_chtlingsstatus_haben_Sie': None,
#  'Email_Opt_Out': False,
#  'R_cksprache_Rechtsanwalt_EB': None,
#  'Welches_befristete_AR_haben_Sie': '32',
#  'use_for_update': '786',
#  'Anspruchsgrundlage_EB1': None,
#  'Mobile': '4917632604730',
#  'Test1': None,
#  'Customer_ID_Woo': '6653',
#  'Kinder_Dokumente': [],
#  'Jobcenter': 'Nein',
#  'Voraussetzungen_erf_llt_ca': None,
#  'Produkt_Erstberatung': None,
#  'Buchung_Ehepartner': None,
#  'Locked__s': False,
#  'Zahlungsweise': None,
#  'Tag': [],
#  'Woo_ID_EB': '165325',
#  'E_Mail_senden_f_r_Support': None,
#  'Owner_Backup': None,
#  'utm_medium': 'organic',
#  '$followers': None,
#  'Update': False,
#  'Haben_Sie_bereits_einen_Antrag_auf_ein_unbefristet': 'Nein, ich habe noch keinen Antrag gestellt',
#  'Info_zu_Kind_er': None,
#  'Ausgang_Antragsverfahren_NE': None,
#  'Doppelbuchung': None,
#  'Anspruchsgrundlage_EB': None,
#  'Mailing_Country': 'Germany',
#  '$locked_for_me': False,
#  'Formel_6': 1,
#  'Wie_ist_ihr_aktueller_Familienstand': 'Ledig',
#  'tracking_referrer1': 'https://migrando.de/linktree/',
#  'Feedback_0_10': None,
#  'Days_Visited': 1,
#  'Sonstige_Details': None,
#  '$followed': False,
#  'Test_Unterlagen': None,
#  '$editable': True,
#  'Sales_Einb_rgerung': 1,
#  'Produkt_EB': 'EinbÃ¼rgerung',
#  'Kaufdatum_Erstberatung': None,
#  'Feedback_Freitext': None,
#  'E_Mail_individuell': None,
#  'Gesamtbetrag_User_Woo': None,
#  'Kaufdatum_EB': '2024-05-23 19:49:38',
#  'Status_R_ckzahlung': None,
#  'Abschluss': '10. Klasse Abschluss',
#  'Gesamtbetrag_Order_Woo': '149.00',
#  'Verheiratet_mit': None,
#  'Bearbeitungshinweis_Kanzlei_EB': None,
#  'Sales_Status': 'SALE',
#  'Beratungsnotizen_EB': None,
#  'Anzahl_verpasster_Anrufe': None,
#  'Kundennummer': '0189975',
#  'Ist_der_aktuelle_Aufenthaltstitel_abgelaufen': 'Ja',
#  'Warum_Stufe_2_oder_3_nicht_erreicht': None,
#  'First_Name': 'Mani',
#  'Followup_NEW': ['POSITIV MB 1',
#   'POSITIV MB CLOSED',
#   'POSITIV MB 2 OFF',
#   'POSITIV OB CLOSED'],
#  'Produkt_Woo': None,
#  'Phone': '+4917632604730',
#  'Asylstatus': None,
#  'geplanter_Anruf': '2024-04-23T15:00:00+02:00',
#  'Feedback_gegeben_NEUES_SYSTEM': None,
#  'NE_erhalten_Datum': None,
#  'Gravity_ID': 'ZqfPGeXEP1',
#  'Beratung_sp_ter': None,
#  'Mailing_City': 'hamburg',
#  'Unsubscribed_Time': None,
#  'Nationalpass1': 'gÃ¼ltiger Nationalpass',
#  'Anruf_7': None,
#  'Anruf_6': None,
#  'Anruf_5': None,
#  'Anruf_4': None,
#  'Anruf_3': None,
#  'EB_NE_erf_llt': 'BOTH',
#  'Anruf_2': 'Erreicht - Zusage',
#  'Anruf_1': 'Erreicht - kein Anspruch',
#  'Vorname_Woo_NE': 'Mani',
#  'utm_term': None,
#  'aktuelles_Ausbildungsverh_ltnis': None,
#  'test_time': '66',
#  'Vorstrafe': 'keine Straftaten',
#  'Gr_nde_f_r_Ablehnung': [],
#  'PLZ_Woo1': '22145',
#  'Last_Name': 'Bakhtiari',
#  'Integrationstest': 'Ich weiÃŸ es nicht',
#  'Abbuchung_2_Rate': None,
#  'Ehepartner_Antragsteller': '0',
#  'Setter': {'name': 'Denis Richter', 'id': '318777000014028001'},
#  'Vollmacht_Ehepartner': None,
#  'Zahlungplan': None,
#  'Datum_der_Absage': '2024-01-14',
#  'Followup': 'beendet',
#  'Kontakt_ist_Antragsteller': '1',
#  'Test_Lookup': None}

# %%
df1 = pd.json_normalize(data)
for col in df1.columns:
    print(col)
# Out:
# E_Mail_senden_Identit_t
# Geburtsjahr
# Antrag_NE_wann_gestellt
# Einreisejahr
# Info_zum_Ehepartner
# $field_states
# Sprachzertifikat_1
# Sonstige_Details_EB
# Erh_lt_Bedarfsgemeinschaft_Geld_vom_Jobcenter
# Interesse_neues_Gesetz
# Nationalpass_Ausnahme1
# $process_flow
# Currency
# Einreisejahr_Deutschland
# EB_neues_Gesetz
# Preis_Raten_EB
# First_Visited_URL
# Anspruchsgrundlage1
# CRM_Campaigns
# Gr_nde_f_r_Ablehnung_EB
# Familienstand
# Mandat_gek_ndigt
# Land
# Anrede1
# Beratung
# Aufenthaltstitel_Telefon_NEU
# Antrag_EB_wann_gestellt
# Abschluss_in_DE
# Datum_letzter_Test_mit_Zeit
# Number_Of_Chats
# Datum_Eintrag_Beratung_sp_ter
# Anzahl_der_Raten_NE2
# Other_Zip
# Mailing_Street
# E_Mail_nach_Telefonberatung
# Average_Time_Spent_Minutes
# Setter_2_optional
# Sales
# E_Mail_Vollmacht_Kontakt
# Rechtm_iger_Aufenthalt_seit
# Ende_Duldung
# Nationalit_t
# Bearbeitungshinweis_Kanzlei
# Other_Street
# Woo_ID_NE
# Unterlagen_Mail_erstellen
# Woo_ID_Identit_t
# Berufsausbildung
# Jahr_Ausbildung_abgeschlossen
# Test_Sprache
# Deutscher_Ehepartner
# EB_erhalten_am
# Datum_der_Doppelbuchung
# $orchestration
# Datum_letzter_Anruf_Ausagehend_Eingehend
# Geburtsdatum_aus_Formular_EB
# Beratung_war_Ja_Backup
# Lead_Test_Feld
# Vollmacht_EB
# Herkunftsland
# Lead_Source
# Last_Missed_Call
# E_Mail_Adresse
# Email
# $currency_symbol
# Visitor_Score
# Einkommen_netto_pro_Monat
# Missed_Calls
# Other_State
# Ausgang_Antragsverfahren_EB
# Followup_After_Sale
# Nachname_Woo
# Last_Activity_Time
# Kaufdatum_Last_Woo
# Produkt_NE
# Contact_ID
# Unsubscribed_Mode
# Woo_ID_Erstberatung
# Exchange_Rate
# Test
# Kinder
# $approved
# Daten_vom_Kunden_aktualisiert_am
# Whatsapp
# Rente
# E_Mail_EB_individuell
# Rentenbeitr_ge_genau
# Erreichbarkeit
# Bemerkungen_Doppelbuchung
# Other_City
# utm_campaign
# Vollmacht_manuelle_EIngabe
# Setter_gesetzt_Datum
# Number_of_Deals
# Alter_Formel
# Home_Phone
# Einkommensart
# zohoworkdriveforcrm__Workdrive_Folder_ID
# Datum_R_ckzahlung
# Sales_Niederlassungserlaubnis
# E_Mail_Woo
# Probleme_mit_Ausl_nderbeh_rde_Telefon
# $zia_owner_assignment
# Status_der_Doppelbuchung
# Anzahl_der_Raten_EB2
# Email_und_Termin_best_tigen
# utm_source
# Dynamischer_Buchungsink_Email_senden
# Gutschein
# Netto
# Mailing_Zip
# Buchhaltung_gepr_ft
# Datum_des_Antrags
# Anspruchsgrundlage
# Sales_Erstberatung
# $review
# Datum_des_Sales
# First_Missed_Call
# Minderj_rhig
# Welches_Aufenthaltsrecht_haben_Sie_aktuell
# utm_content
# Social_Media_ID
# Stadt_Woo
# Modified_Time
# Date_of_Birth
# Telefon_Woo
# E_Mail_Vollmacht_Ehepartner
# Anrede
# First_Visited_Time
# ID_der_Doppelbuchung
# G_ltiger_Nationalpass
# $in_merge
# Referrer
# Grund_der_Absage
# Owner_Backup_Status
# Nachname_Backup
# $approval_state
# Dynamischer_Buchungslink
# Identit_t_gesichert_Stufe_3a
# Beratung_Ja_Nein
# Geburtsdatum_aus_Formular
# Stornierte_Sales_Insgesamt
# E_Mail_senden_Support
# Mailing_State
# Multizeile_2
# Test9
# Test8
# Test7
# Setter_3_optional
# Test6
# Anzahl_Kinder_unter_25_Jahre
# Test5
# Test4
# Other_Country
# Erreichbarkeit_Uhrzeit_Liste
# Test3
# Google_und_Trustpilot_Bewertung
# Test2
# Jahr_AR_beantragt_bekommen
# Wohnraum
# Zoho_Books_ID
# Haben_Sie_bereits_einen_Antrag_auf_Einb_rgerung_ge
# $state
# Sonstiges_befristetes_AR_Aufenthaltstitel1
# id
# Vollmacht
# missed_calls1
# Beschreibe_den_Strafvorwurf
# Vollmacht_Identit_t
# Created_Time
# E_Mail_senden_Einb_rgerung
# Sprachzertifikat1
# Rechnung_stellen
# Erreichbarkeit_Uhrzeit
# Integrationsnachweis_1
# reset
# Einb_rgerungszusicherung
# Preis_Raten_NE
# Last_Visited_Time
# Stra_e_u_Hausnummer
# Beziehung_Letzter_Test_Anruf
# Quantity_Products
# Kaufdatum_NE
# Datum_des_Antrags_EB
# ID_Stufe_3
# $canvas_id
# Last_updated_by
# Salutation
# Erreichbarkeit_Datum_Zeit
# Full_Name
# zohoworkdriveforcrm__Workdrive_Folder_URL
# Kaufdatum_First_Woo
# Minderj_hrige_Kinder_Antragsteller
# Welchen_Fl_chtlingsstatus_haben_Sie
# Email_Opt_Out
# R_cksprache_Rechtsanwalt_EB
# Welches_befristete_AR_haben_Sie
# use_for_update
# Anspruchsgrundlage_EB1
# Mobile
# Test1
# Customer_ID_Woo
# Kinder_Dokumente
# Jobcenter
# Voraussetzungen_erf_llt_ca
# Produkt_Erstberatung
# Buchung_Ehepartner
# Locked__s
# Zahlungsweise
# Tag
# Woo_ID_EB
# E_Mail_senden_f_r_Support
# Owner_Backup
# utm_medium
# $followers
# Update
# Haben_Sie_bereits_einen_Antrag_auf_ein_unbefristet
# Info_zu_Kind_er
# Ausgang_Antragsverfahren_NE
# Doppelbuchung
# Anspruchsgrundlage_EB
# Mailing_Country
# $locked_for_me
# Formel_6
# Wie_ist_ihr_aktueller_Familienstand
# tracking_referrer1
# Feedback_0_10
# Days_Visited
# Sonstige_Details
# $followed
# Test_Unterlagen
# $editable
# Sales_Einb_rgerung
# Produkt_EB
# Kaufdatum_Erstberatung
# Feedback_Freitext
# E_Mail_individuell
# Gesamtbetrag_User_Woo
# Kaufdatum_EB
# Status_R_ckzahlung
# Abschluss
# Gesamtbetrag_Order_Woo
# Verheiratet_mit
# Bearbeitungshinweis_Kanzlei_EB
# Sales_Status
# Beratungsnotizen_EB
# Anzahl_verpasster_Anrufe
# Kundennummer
# Ist_der_aktuelle_Aufenthaltstitel_abgelaufen
# Warum_Stufe_2_oder_3_nicht_erreicht
# First_Name
# Followup_NEW
# Produkt_Woo
# Phone
# Asylstatus
# geplanter_Anruf
# Feedback_gegeben_NEUES_SYSTEM
# NE_erhalten_Datum
# Gravity_ID
# Beratung_sp_ter
# Mailing_City
# Unsubscribed_Time
# Nationalpass1
# Anruf_7
# Anruf_6
# Anruf_5
# Anruf_4
# Anruf_3
# EB_NE_erf_llt
# Anruf_2
# Anruf_1
# Vorname_Woo_NE
# utm_term
# aktuelles_Ausbildungsverh_ltnis
# test_time
# Vorstrafe
# Gr_nde_f_r_Ablehnung
# PLZ_Woo1
# Last_Name
# Integrationstest
# Abbuchung_2_Rate
# Ehepartner_Antragsteller
# Vollmacht_Ehepartner
# Zahlungplan
# Datum_der_Absage
# Followup
# Kontakt_ist_Antragsteller
# Test_Lookup
# Owner.name
# Owner.id
# Owner.email
# $approval.delegate
# $approval.approve
# $approval.reject
# $approval.resubmit
# $review_process.approve
# $review_process.reject
# $review_process.resubmit
# Layout.name
# Layout.id
# Modified_By.name
# Modified_By.id
# Modified_By.email
# Created_By.name
# Created_By.id
# Created_By.email
# Setter.name
# Setter.id

# %%
new_df = df1[['Abschluss', 'Abschluss_in_DE', 'Deutscher_Ehepartner', 'EB_NE_erf_llt', 'Einreisejahr', 'Haben_Sie_bereits_einen_Antrag_auf_Einb_rgerung_ge', 'Haben_Sie_bereits_einen_Antrag_auf_ein_unbefristet', 'Integrationstest', 'Jahr_AR_beantragt_bekommen', 'Jobcenter', 'Kinder', 'Netto', 'Rente', 'Sprachzertifikat1', 'Test_Sprache', 'Welches_befristete_AR_haben_Sie', 'Wie_ist_ihr_aktueller_Familienstand', 'Beratung', 'G_ltiger_Nationalpass', 'id', 'Sales']]

new_df_1 = new_df.copy()

new_df_1.columns = ['1-Abschluss', '1-Abschluss in DE', '1-Deutscher Ehepartner', '1-EB/NE erfllt?', '1-Einreisejahr', '1-Antrag EB', '1-Antrag NE', '1-Integrationstest', '1-Jahr AR beantragt/bekommen', '1-Jobcenter', '1-Kinder', '1-Netto', '1-Rente', '1-Sprachzertifikat', '1-Test Sprache', '1-Welches befristete AR haben Sie?', '1-Wie ist ihr aktueller Familienstand?', '1-Beratung?', '1-Gltiger Nationalpass', 'Id', 'Sales']

df = new_df_1
df
# Out:
#             1-Abschluss 1-Abschluss in DE 1-Deutscher Ehepartner  \
# 0  10. Klasse Abschluss                Ja                   None
#
#   1-EB/NE erfllt?          1-Einreisejahr  \
# 0            BOTH  In Deutschland geboren
#
#                                1-Antrag EB  \
# 0  Ja, mein Antrag wird aktuell bearbeitet
#
#                                   1-Antrag NE  1-Integrationstest  \
# 0  Nein, ich habe noch keinen Antrag gestellt  Ich weiÃŸ es nicht
#
#   1-Jahr AR beantragt/bekommen 1-Jobcenter  ...      1-Netto         1-Rente  \
# 0                         2019        Nein  ...  0€ bis 600€  48 - 60 Monate
#
#   1-Sprachzertifikat 1-Test Sprache 1-Welches befristete AR haben Sie?  \
# 0               Nein        Deutsch                                 32
#
#   1-Wie ist ihr aktueller Familienstand? 1-Beratung? 1-Gltiger Nationalpass  \
# 0                                  Ledig          Ja                     Ja
#
#                    Id Sales
# 0  318777000096411067     1
#
# [1 rows x 21 columns]

# %%
#df = df[df["1-Welches Aufenthaltsrecht haben Sie aktuell?"] == "ACHTUNG TEST 3.0"]
new_df = df1[['Abschluss', 'Abschluss_in_DE', 'Deutscher_Ehepartner', 'EB_NE_erf_llt', 'Einreisejahr', 'Haben_Sie_bereits_einen_Antrag_auf_Einb_rgerung_ge', 'Haben_Sie_bereits_einen_Antrag_auf_ein_unbefristet', 'Integrationstest', 'Jahr_AR_beantragt_bekommen', 'Jobcenter', 'Kinder', 'Netto', 'Rente', 'Sprachzertifikat1', 'Test_Sprache', 'Welches_befristete_AR_haben_Sie', 'Wie_ist_ihr_aktueller_Familienstand', 'Beratung', 'G_ltiger_Nationalpass', 'id', 'Sales']]
new_df_1 = new_df.copy()
new_df_1.columns = ['1-Abschluss', '1-Abschluss in DE', '1-Deutscher Ehepartner', '1-EB/NE erfllt?', '1-Einreisejahr', '1-Antrag EB', '1-Antrag NE', '1-Integrationstest', '1-Jahr AR beantragt/bekommen', '1-Jobcenter', '1-Kinder', '1-Netto', '1-Rente', '1-Sprachzertifikat', '1-Test Sprache', '1-Welches befristete AR haben Sie?', '1-Wie ist ihr aktueller Familienstand?', '1-Beratung?', '1-Gltiger Nationalpass', 'Id', 'Sales']
df = new_df_1
df
# Change type of "Sales" column to int64
df["Sales"] = df["Sales"].astype('int64')
# Add conditional column "SalesCount"
df["SalesCount"] = df["Sales"].apply(lambda x: 1 if x > 0 else 0)

# Change type of "SalesCount" column to int64
df["SalesCount"] = df["SalesCount"].astype('int64')

# Filter rows where "Sales" is not null and "1-Abschluss" is not empty
df = df[df["Sales"].notna() & (df["1-Abschluss"] != "")]

# Replace values in "1-Abschluss in DE" column
df["1-Abschluss in DE"] = df["1-Abschluss in DE"].replace("", "Not Asked")

# Replace values in "1-Deutscher Ehepartner" column
df["1-Deutscher Ehepartner"] = df["1-Deutscher Ehepartner"].replace("", "Not Asked")

# (No operation needed for "each true" steps in pandas)

# Replace values in "1-Einreisejahr" column
df["1-Einreisejahr"] = df["1-Einreisejahr"].replace({"Vor 2014": "Vor 2015", "2011 oder davor": "Vor 2015", "2012": "Vor 2015", "2013": "Vor 2015", "2014": "Vor 2015"})

# Filter rows where "1-Antrag EB" is not empty
df = df[df["1-Antrag EB"] != ""]

# Replace values in "1-Antrag NE" column
df["1-Antrag NE"] = df["1-Antrag NE"].replace("", "Not Asked")

# Replace values in "1-Jahr AR beantragt/bekommen" column
df["1-Jahr AR beantragt/bekommen"] = df["1-Jahr AR beantragt/bekommen"].replace({"Vor 2014": "Vor 2015", "2014": "Vor 2015", "": "Not Asked"})

# Replace values in "1-Jobcenter" column
df["1-Jobcenter"] = df["1-Jobcenter"].replace("", "Not Asked")

# Replace values in "1-Rente" column
df["1-Rente"] = df["1-Rente"].replace("", "Not Asked")

# Remove specified columns
#df = df.drop(columns=["1-Sonstigs befristetes AR? / Aufenthaltstitel"])

# Filter rows where "1-Sprachzertifikat" is not empty
df = df[df["1-Sprachzertifikat"] != ""]

# Replace values in "1-Test Sprache" column
df["1-Test Sprache"] = df["1-Test Sprache"].replace("", "Deutsch")

# Remove specified columns
#df = df.drop(columns=["1-Welchen Flüchtlingsstatus haben Sie?", "1-Welches Aufenthaltsrecht haben Sie aktuell?"])

# Filter rows where "1-Beratung?" is "Ja" or "Nein"
df = df[df["1-Beratung?"].isin(["Ja", "Nein"])]

# Remove specified column
#df = df.drop(columns=["1-Abschluss_copy"])

# Filter rows where "1-Welches befristete AR haben Sie?" is not empty
df = df[df["1-Welches befristete AR haben Sie?"] != ""]

# Display the final dataframe
#print(df)
df = df.applymap(remove_non_ascii)

df
# Out:
# C:\Users\Migrando1\AppData\Local\Temp\ipykernel_5156\2175606905.py:63: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(remove_non_ascii)
#             1-Abschluss 1-Abschluss in DE 1-Deutscher Ehepartner  \
# 0  10. Klasse Abschluss                Ja                   None
#
#   1-EB/NE erfllt?          1-Einreisejahr  \
# 0            BOTH  In Deutschland geboren
#
#                                1-Antrag EB  \
# 0  Ja, mein Antrag wird aktuell bearbeitet
#
#                                   1-Antrag NE 1-Integrationstest  \
# 0  Nein, ich habe noch keinen Antrag gestellt   Ich wei es nicht
#
#   1-Jahr AR beantragt/bekommen 1-Jobcenter  ...         1-Rente  \
# 0                         2019        Nein  ...  48 - 60 Monate
#
#   1-Sprachzertifikat 1-Test Sprache 1-Welches befristete AR haben Sie?  \
# 0               Nein        Deutsch                                 32
#
#   1-Wie ist ihr aktueller Familienstand? 1-Beratung? 1-Gltiger Nationalpass  \
# 0                                  Ledig          Ja                     Ja
#
#                    Id Sales SalesCount
# 0  318777000096411067     1          1
#
# [1 rows x 22 columns]

# %%
import pandas as pd

# Replace 'filename.txt' with your actual file path
data = pd.read_csv('_-E_Mail_senden.txt')

# Print the DataFrame
print(data)
# Out:
# Empty DataFrame
# Columns: [{"E_Mail_senden_Identit_t":null, Geburtsjahr:2003, Owner:{"name":"Andreas Noack", id:"318777000017206719", email:"andreasnoack@migrando.de"}, Antrag_NE_wann_gestellt:null, Einreisejahr:"In Deutschland geboren", Info_zum_Ehepartner:null, $field_states:null, Sprachzertifikat_1:["Deutscher Schulabschluss"], Sonstige_Details_EB:null, Erh_lt_Bedarfsgemeinschaft_Geld_vom_Jobcenter:"Nein", Interesse_neues_Gesetz:true, Nationalpass_Ausnahme1:null, $process_flow:false, Currency:"EUR", Einreisejahr_Deutschland:"2018-11-01", EB_neues_Gesetz:"Nein", Preis_Raten_EB:"149.00", $approval:{"delegate":false, approve:false, reject:false, resubmit:false}, First_Visited_URL:"https://migrando.de/linktree/", Anspruchsgrundlage1:null, CRM_Campaigns:[], Gr_nde_f_r_Ablehnung_EB:null, Familienstand:"ledig", Mandat_gek_ndigt:false, Land:null, Anrede1:"Herr", Beratung:"Ja", Aufenthaltstitel_Telefon_NEU:"32", Antrag_EB_wann_gestellt:"Vor mehr als 1 Jahr", Abschluss_in_DE:"Ja", Datum_letzter_Test_mit_Zeit:"2024-01-14T02:32:00+01:00", Number_Of_Chats:0, Datum_Eintrag_Beratung_sp_ter:null, Anzahl_der_Raten_NE2:null, $review_process:{"approve":false, reject:false.1, resubmit:false}.1, Other_Zip:"22145", Mailing_Street:"Lehàr Straße 62a", E_Mail_nach_Telefonberatung:null, Average_Time_Spent_Minutes:3.66, Setter_2_optional:null, Sales:1, E_Mail_Vollmacht_Kontakt:null, Rechtm_iger_Aufenthalt_seit:null, Ende_Duldung:null, Nationalit_t:"Iran", Bearbeitungshinweis_Kanzlei:null, Other_Street:"Lehàr Straße 62a", Woo_ID_NE:null, Unterlagen_Mail_erstellen:null, Woo_ID_Identit_t:null, Berufsausbildung:"Ungelernt", Jahr_Ausbildung_abgeschlossen:null, Test_Sprache:"Deutsch", Deutscher_Ehepartner:null, EB_erhalten_am:null, Datum_der_Doppelbuchung:null, $orchestration:false, Datum_letzter_Anruf_Ausagehend_Eingehend:"2024-05-24T13:14:11+02:00", Geburtsdatum_aus_Formular_EB:null, Beratung_war_Ja_Backup:true, Lead_Test_Feld:null, Layout:{"name":"Sales Mitarbeiter", id:"318777000000032039"}, Vollmacht_EB:null, Herkunftsland:null, Lead_Source:"TikTok", Last_Missed_Call:"2024-05-27T11:39:17+02:00", E_Mail_Adresse:null, Email:"maniibkh@gmail.com", $currency_symbol:"\u20ac", Visitor_Score:"653", Einkommen_netto_pro_Monat:950, Missed_Calls:5, Other_State:"Nordrheinwestfalen", Ausgang_Antragsverfahren_EB:null, Followup_After_Sale:[], Nachname_Woo:"Bakhtiari", Last_Activity_Time:"2024-05-27T11:45:59+02:00", Kaufdatum_Last_Woo:"2024-05-23 19:49:38", Produkt_NE:null, Contact_ID:"318777000145496147", Unsubscribed_Mode:null, Woo_ID_Erstberatung:null, Exchange_Rate:1, Test:null, Kinder:"0", $approved:true, Daten_vom_Kunden_aktualisiert_am:null, Whatsapp:"4917632604730", Rente:"48 - 60 Monate", E_Mail_EB_individuell:null, Rentenbeitr_ge_genau:"0", Erreichbarkeit:null, ...]
# Index: []
#
# [0 rows x 314 columns]
